# %%
### 네이버 크롤링 (https://finance.naver.com/ 에 접속하여 달러환률 정보 확인!!)
from bs4 import BeautifulSoup
import urllib.request as rq

url = "https://finance.naver.com/"
resp = rq.urlopen(url).read()

data = resp.decode("euc-kr")

soup = BeautifulSoup(data,'html.parser')

price = soup.select_one("div.group1 > table.tbl_home > tbody > tr.up.bold > td")
print("미국 환율 : " + price.string + " 원")
# Out:
# 미국 환율 : 1,273.20 원

# %%
### "https://finance.naver.com/" 에서 거래 상위 10개를 추출하여 출력하세요!!!
### 종목과 가격 => 대한전지 2140 와 같은 식으로 출력

from bs4 import BeautifulSoup
import urllib.request as rq

url = "https://finance.naver.com/"
resp = rq.urlopen(url).read()

data = resp.decode("euc-kr")

soup = BeautifulSoup(data,'html.parser')

top = soup.select("div.group_type.is_active > table.tbl_home > tbody > tr > th > a")
price2 = soup.select("div.group_type.is_active > table.tbl_home > tbody > tr > td")

dic = {}
lst = []
lst2 = []
for i in price2:
    if i.string != None:
        if i.string != '보합':
            lst.append(i.string)
        
for j in top:
    lst2.append(j.string)

for k in range(0,10):
    print(f"{k+1}위 {lst2[k]} - {lst[k]}원")


# or

from bs4 import BeautifulSoup
import urllib.request as rq

url = "https://finance.naver.com/"
resp = rq.urlopen(url).read()

data = resp.decode("euc-kr")

soup = BeautifulSoup(data,'html.parser')

top = soup.select("div.group_type.is_active > table.tbl_home > tbody > tr > th > a")
top_list_pr = soup.select("div.group_type.is_active > table.tbl_home > tbody > tr > td")
top_list =[top[i].string for i in range(10)]
top_list_pr1 = [top_list_pr[i].string for i in range(0,30,3)]

for i in range(10):
    print(f"{i+1}위 {top_list[i]} - {top_list_pr1[i]}원")
# Out:
# 1위 대한전선 - 2,320원
# 2위 KODEX 200선물인버스2X - 2,670원
# 3위 부산주공 - 880원
# 4위 이스트아시아홀딩스 - 314원
# 5위 소니드 - 1,350원
# 6위 GS글로벌 - 4,590원
# 7위 삼성 인버스 2X WTI원유 선물 ETN - 125원
# 8위 대원전선 - 2,295원
# 9위 TYM - 3,385원
# 10위 휴림로봇 - 3,720원
# 1위 대한전선 - 2,320원
# 2위 KODEX 200선물인버스2X - 2,670원
# 3위 부산주공 - 880원
# 4위 이스트아시아홀딩스 - 314원
# 5위 소니드 - 1,350원
# 6위 GS글로벌 - 4,590원
# 7위 삼성 인버스 2X WTI원유 선물 ETN - 125원
# 8위 대원전선 - 2,295원
# 9위 TYM - 3,385원
# 10위 휴림로봇 - 3,720원

# %%
## 링크에 있는 내용을 한꺼번에 처리하기

# 재귀적으로 탐색하기 위해서 사용하는 함수.. urljoin(base,"상대경로") 함수
# 특정 경로를 찾아서 작업을 할때 사용하는 함수
from urllib.parse import urljoin

base = "http://example.com/html/a.html"

### 상대 경로
print(urljoin(base, "b.html"))
print(urljoin(base,"sub/c.html"))
print(urljoin(base, "../index.html"))
print(urljoin(base, "../img/home.png"))
print(urljoin(base, "../css/home.css"))

### 절대 경로
print(urljoin(base, "/index.html"))     # 절대 경로
print(urljoin(base, "http://otherExample.com/wiki"))    # 뒤에 있는 값이 주소인 경우 덮어쓰여진다.
print(urljoin(base, "//otherExample.com/test"))         # //를 사용하면 해당 주소로 덮어쓰여진다.
# Out:
# http://example.com/html/b.html
# http://example.com/html/sub/c.html
# http://example.com/index.html
# http://example.com/img/home.png
# http://example.com/css/home.css
# http://example.com/index.html
# http://otherExample.com/wiki
# http://otherExample.com/test

# %%
## 처리 순서
# 1. HTML 분석
# 2. 링크 추출
# 3. 각 링크 대상에 대해 다음 동작을 구동함 
#   3-1. 다운로드 파일인 경우 다운로드
#   3-2. 파일이 HTML이라면, 1번 으로 돌아가 다시 실행

# %%
## 모든 페이지를 한꺼번에 다운받는 프로그렘을 만들기 (하기전에 사이트정보를 분석해야한다.)

## 모듈
from bs4 import BeautifulSoup
from urllib.request import *
from urllib.parse import * 
from os import makedirs
import os.path, time, re

## 처리한 내용이 파일인지 여부 확인을 위한 변수
proc_files = {}      # 딕셔너리 생성

# HTML 내부에 있는 링크를 추출하는 함수를 동작
def enum_links(html, base):
    soup = BeautifulSoup(html, "html.parser")
    links = soup.select("link[rel ='stylesheet']")      ## CSS 참조
    links += soup.select("a[href]")     # 링크 참조
    
    result = []
    # href 속성을 추출하고, 링크를 절대 경로로 변환하여 저장
    for a in links:
        href = a.attrs['href']
        url = urljoin(base, href)
        result.append(url)
    return result

# 파일을 다운로드하고 저장하는 함수
def download_file(url):
    o = urlparse(url)
    savepath = "./" + o.netloc + o.path     ## netloc = http://를 제외한 도메인 주소 , path = 도메인 뒤에 있는 경로
    if re.search(r"/$", savepath):          # savepath의 마지막이 "/"라면
        savepath += "index.html"            # 기본 문서
    savedir = os.path.dirname(savepath)
    
    # 모두 다운로드됐는지 여부 확인
    if os.path.exists(savepath):
        return savepath
    
    # 다운로드 안됐을 시 다운받을 디렉터리를 생성
    if not os.path.exists(savedir):
        print("mkdir = ", savedir)
        makedirs(savedir)
    
    # 파일 다운받기
    try:
        print("download = ", url)
        urlretrieve(url,savepath)
        time.sleep(1)   # 1초 쉬었다가 동작
        return savepath
    except Exception as e:
        print("다운로드 오류 발생 : ", url)
        print("다운로드 에러 내용 : ", e)
        return None
    
# HTML을 분석하고 다운받는 함수
def analyze_html(url, root_url):
    savepath = download_file(url)
    if savepath is None:
        return
    if savepath in proc_files:      # 이미 처리되었다면 실행하지 않음
        return 
    proc_files[savepath] = True
    print("analyze_html=",url)
    
    # 링크 추출 
    html = open(savepath, "r", encoding="utf-8").read()
    links = enum_links(html, url)
    
    for link_url in links:
        # 링크가 루트 이외의 경로를 나타낸다면 무시
        if link_url.find(root_url) != 0:
            if not re.search(r".css$", link_url):
                continue
            
        # HTML이라면
        if re.search(r".(html|htm)$", link_url):
            # 재귀적으로 html 파일 분석
            analyze_html(link_url, root_url)
            continue
        # 기타 파일
        download_file(link_url)
        
# 일반 파이썬 파일인 경우 사용      
# if __name__ == "__main__":
#     # url에 있는 모든 것 다운받기
#     url = "https://docs.python.org/3.10/library/"
#     analyze_html(url, url)

url = "https://docs.python.org/3.10/library/"
analyze_html(url, url)
# Out:
# mkdir =  ./docs.python.org/3.10/library
# download =  https://docs.python.org/3.10/library/
# analyze_html= https://docs.python.org/3.10/library/
# mkdir =  ./docs.python.org/3.10/_static
# download =  https://docs.python.org/3.10/_static/pygments.css
# download =  https://docs.python.org/3.10/library/intro.html
# analyze_html= https://docs.python.org/3.10/library/intro.html
# download =  https://docs.python.org/3.10/library/functions.html
# analyze_html= https://docs.python.org/3.10/library/functions.html
# download =  https://docs.python.org/3.10/library/constants.html
# analyze_html= https://docs.python.org/3.10/library/constants.html
# download =  https://docs.python.org/3.10/library/stdtypes.html
# analyze_html= https://docs.python.org/3.10/library/stdtypes.html
# download =  https://docs.python.org/3.10/library/exceptions.html
# analyze_html= https://docs.python.org/3.10/library/exceptions.html
# download =  https://docs.python.org/3.10/library/text.html
# analyze_html= https://docs.python.org/3.10/library/text.html
# download =  https://docs.python.org/3.10/library/string.html
# analyze_html= https://docs.python.org/3.10/library/string.html
# download =  https://docs.python.org/3.10/library/re.html
# analyze_html= https://docs.python.org/3.10/library/re.html
# download =  https://docs.python.org/3.10/library/difflib.html
# analyze_html= https://docs.python.org/3.10/library/difflib.html
# download =  https://docs.python.org/3.10/library/textwrap.html
# analyze_html= https://docs.python.org/3.10/library/textwrap.html
# download =  https://docs.python.org/3.10/library/unicodedata.html
# analyze_html= https://docs.python.org/3.10/library/unicodedata.html
# download =  https://docs.python.org/3.10/library/stringprep.html
# analyze_html= https://docs.python.org/3.10/library/stringprep.html
# download =  https://docs.python.org/3.10/library/readline.html
# analyze_html= https://docs.python.org/3.10/library/readline.html
# download =  https://docs.python.org/3.10/library/rlcompleter.html
# analyze_html= https://docs.python.org/3.10/library/rlcompleter.html
# download =  https://docs.python.org/3.10/library/binary.html
# analyze_html= https://docs.python.org/3.10/library/binary.html
# download =  https://docs.python.org/3.10/library/struct.html
# analyze_html= https://docs.python.org/3.10/library/struct.html
# download =  https://docs.python.org/3.10/library/codecs.html
# analyze_html= https://docs.python.org/3.10/library/codecs.html
# download =  https://docs.python.org/3.10/library/datatypes.html
# analyze_html= https://docs.python.org/3.10/library/datatypes.html
# download =  https://docs.python.org/3.10/library/datetime.html
# analyze_html= https://docs.python.org/3.10/library/datetime.html
# download =  https://docs.python.org/3.10/library/zoneinfo.html
# analyze_html= https://docs.python.org/3.10/library/zoneinfo.html
# download =  https://docs.python.org/3.10/library/calendar.html
# analyze_html= https://docs.python.org/3.10/library/calendar.html
# download =  https://docs.python.org/3.10/library/collections.html
# analyze_html= https://docs.python.org/3.10/library/collections.html
# download =  https://docs.python.org/3.10/library/collections.abc.html
# analyze_html= https://docs.python.org/3.10/library/collections.abc.html
# download =  https://docs.python.org/3.10/library/heapq.html
# analyze_html= https://docs.python.org/3.10/library/heapq.html
# download =  https://docs.python.org/3.10/library/bisect.html
# analyze_html= https://docs.python.org/3.10/library/bisect.html
# download =  https://docs.python.org/3.10/library/array.html
# analyze_html= https://docs.python.org/3.10/library/array.html
# download =  https://docs.python.org/3.10/library/weakref.html
# analyze_html= https://docs.python.org/3.10/library/weakref.html
# download =  https://docs.python.org/3.10/library/types.html
# analyze_html= https://docs.python.org/3.10/library/types.html
# download =  https://docs.python.org/3.10/library/copy.html
# analyze_html= https://docs.python.org/3.10/library/copy.html
# download =  https://docs.python.org/3.10/library/pprint.html
# analyze_html= https://docs.python.org/3.10/library/pprint.html
# download =  https://docs.python.org/3.10/library/reprlib.html
# analyze_html= https://docs.python.org/3.10/library/reprlib.html
# download =  https://docs.python.org/3.10/library/enum.html
# analyze_html= https://docs.python.org/3.10/library/enum.html
# download =  https://docs.python.org/3.10/library/graphlib.html
# analyze_html= https://docs.python.org/3.10/library/graphlib.html
# download =  https://docs.python.org/3.10/library/numeric.html
# analyze_html= https://docs.python.org/3.10/library/numeric.html
# download =  https://docs.python.org/3.10/library/numbers.html
# analyze_html= https://docs.python.org/3.10/library/numbers.html
# download =  https://docs.python.org/3.10/library/math.html
# analyze_html= https://docs.python.org/3.10/library/math.html
# download =  https://docs.python.org/3.10/library/cmath.html
# analyze_html= https://docs.python.org/3.10/library/cmath.html
# download =  https://docs.python.org/3.10/library/decimal.html
# analyze_html= https://docs.python.org/3.10/library/decimal.html
# download =  https://docs.python.org/3.10/library/fractions.html
# analyze_html= https://docs.python.org/3.10/library/fractions.html
# download =  https://docs.python.org/3.10/library/random.html
# analyze_html= https://docs.python.org/3.10/library/random.html
# download =  https://docs.python.org/3.10/library/statistics.html
# analyze_html= https://docs.python.org/3.10/library/statistics.html
# download =  https://docs.python.org/3.10/library/functional.html
# analyze_html= https://docs.python.org/3.10/library/functional.html
# download =  https://docs.python.org/3.10/library/itertools.html
# analyze_html= https://docs.python.org/3.10/library/itertools.html
# download =  https://docs.python.org/3.10/library/functools.html
# analyze_html= https://docs.python.org/3.10/library/functools.html
# download =  https://docs.python.org/3.10/library/operator.html
# analyze_html= https://docs.python.org/3.10/library/operator.html
# download =  https://docs.python.org/3.10/library/filesys.html
# analyze_html= https://docs.python.org/3.10/library/filesys.html
# download =  https://docs.python.org/3.10/library/pathlib.html
# analyze_html= https://docs.python.org/3.10/library/pathlib.html
# download =  https://docs.python.org/3.10/library/os.path.html
# analyze_html= https://docs.python.org/3.10/library/os.path.html
# download =  https://docs.python.org/3.10/library/fileinput.html
# analyze_html= https://docs.python.org/3.10/library/fileinput.html
# download =  https://docs.python.org/3.10/library/stat.html
# analyze_html= https://docs.python.org/3.10/library/stat.html
# download =  https://docs.python.org/3.10/library/filecmp.html
# analyze_html= https://docs.python.org/3.10/library/filecmp.html
# download =  https://docs.python.org/3.10/library/tempfile.html
# analyze_html= https://docs.python.org/3.10/library/tempfile.html
# download =  https://docs.python.org/3.10/library/glob.html
# analyze_html= https://docs.python.org/3.10/library/glob.html
# download =  https://docs.python.org/3.10/library/fnmatch.html
# analyze_html= https://docs.python.org/3.10/library/fnmatch.html
# download =  https://docs.python.org/3.10/library/linecache.html
# analyze_html= https://docs.python.org/3.10/library/linecache.html
# download =  https://docs.python.org/3.10/library/shutil.html
# analyze_html= https://docs.python.org/3.10/library/shutil.html
# download =  https://docs.python.org/3.10/library/persistence.html
# analyze_html= https://docs.python.org/3.10/library/persistence.html
# download =  https://docs.python.org/3.10/library/pickle.html
# analyze_html= https://docs.python.org/3.10/library/pickle.html
# download =  https://docs.python.org/3.10/library/copyreg.html
# analyze_html= https://docs.python.org/3.10/library/copyreg.html
# download =  https://docs.python.org/3.10/library/shelve.html
# analyze_html= https://docs.python.org/3.10/library/shelve.html
# download =  https://docs.python.org/3.10/library/marshal.html
# analyze_html= https://docs.python.org/3.10/library/marshal.html
# download =  https://docs.python.org/3.10/library/dbm.html
# analyze_html= https://docs.python.org/3.10/library/dbm.html
# download =  https://docs.python.org/3.10/library/sqlite3.html
# analyze_html= https://docs.python.org/3.10/library/sqlite3.html
# download =  https://docs.python.org/3.10/library/archiving.html
# analyze_html= https://docs.python.org/3.10/library/archiving.html
# download =  https://docs.python.org/3.10/library/zlib.html
# analyze_html= https://docs.python.org/3.10/library/zlib.html
# download =  https://docs.python.org/3.10/library/gzip.html
# analyze_html= https://docs.python.org/3.10/library/gzip.html
# download =  https://docs.python.org/3.10/library/bz2.html
# analyze_html= https://docs.python.org/3.10/library/bz2.html
# download =  https://docs.python.org/3.10/library/lzma.html
# analyze_html= https://docs.python.org/3.10/library/lzma.html
# download =  https://docs.python.org/3.10/library/zipfile.html
# analyze_html= https://docs.python.org/3.10/library/zipfile.html
# download =  https://docs.python.org/3.10/library/tarfile.html
# analyze_html= https://docs.python.org/3.10/library/tarfile.html
# download =  https://docs.python.org/3.10/library/fileformats.html
# analyze_html= https://docs.python.org/3.10/library/fileformats.html
# download =  https://docs.python.org/3.10/library/csv.html
# analyze_html= https://docs.python.org/3.10/library/csv.html
# download =  https://docs.python.org/3.10/library/configparser.html
# analyze_html= https://docs.python.org/3.10/library/configparser.html
# download =  https://docs.python.org/3.10/library/netrc.html
# analyze_html= https://docs.python.org/3.10/library/netrc.html
# download =  https://docs.python.org/3.10/library/plistlib.html
# analyze_html= https://docs.python.org/3.10/library/plistlib.html
# download =  https://docs.python.org/3.10/library/crypto.html
# analyze_html= https://docs.python.org/3.10/library/crypto.html
# download =  https://docs.python.org/3.10/library/hashlib.html
# analyze_html= https://docs.python.org/3.10/library/hashlib.html
# download =  https://docs.python.org/3.10/library/hmac.html
# analyze_html= https://docs.python.org/3.10/library/hmac.html
# download =  https://docs.python.org/3.10/library/secrets.html
# analyze_html= https://docs.python.org/3.10/library/secrets.html
# download =  https://docs.python.org/3.10/library/allos.html
# analyze_html= https://docs.python.org/3.10/library/allos.html
# download =  https://docs.python.org/3.10/library/os.html
# analyze_html= https://docs.python.org/3.10/library/os.html
# download =  https://docs.python.org/3.10/library/io.html
# analyze_html= https://docs.python.org/3.10/library/io.html
# download =  https://docs.python.org/3.10/library/time.html
# analyze_html= https://docs.python.org/3.10/library/time.html
# download =  https://docs.python.org/3.10/library/argparse.html
# analyze_html= https://docs.python.org/3.10/library/argparse.html
# download =  https://docs.python.org/3.10/library/getopt.html
# analyze_html= https://docs.python.org/3.10/library/getopt.html
# download =  https://docs.python.org/3.10/library/logging.html
# analyze_html= https://docs.python.org/3.10/library/logging.html
# download =  https://docs.python.org/3.10/library/logging.config.html
# analyze_html= https://docs.python.org/3.10/library/logging.config.html
# download =  https://docs.python.org/3.10/library/logging.handlers.html
# analyze_html= https://docs.python.org/3.10/library/logging.handlers.html
# download =  https://docs.python.org/3.10/library/getpass.html
# analyze_html= https://docs.python.org/3.10/library/getpass.html
# download =  https://docs.python.org/3.10/library/curses.html
# analyze_html= https://docs.python.org/3.10/library/curses.html
# download =  https://docs.python.org/3.10/library/curses.ascii.html
# analyze_html= https://docs.python.org/3.10/library/curses.ascii.html
# download =  https://docs.python.org/3.10/library/curses.panel.html
# analyze_html= https://docs.python.org/3.10/library/curses.panel.html
# download =  https://docs.python.org/3.10/library/platform.html
# analyze_html= https://docs.python.org/3.10/library/platform.html
# download =  https://docs.python.org/3.10/library/errno.html
# analyze_html= https://docs.python.org/3.10/library/errno.html
# download =  https://docs.python.org/3.10/library/ctypes.html
# analyze_html= https://docs.python.org/3.10/library/ctypes.html
# download =  https://docs.python.org/3.10/library/concurrency.html
# analyze_html= https://docs.python.org/3.10/library/concurrency.html
# download =  https://docs.python.org/3.10/library/threading.html
# analyze_html= https://docs.python.org/3.10/library/threading.html
# download =  https://docs.python.org/3.10/library/multiprocessing.html
# analyze_html= https://docs.python.org/3.10/library/multiprocessing.html
# download =  https://docs.python.org/3.10/library/multiprocessing.shared_memory.html
# analyze_html= https://docs.python.org/3.10/library/multiprocessing.shared_memory.html
# download =  https://docs.python.org/3.10/library/concurrent.html
# analyze_html= https://docs.python.org/3.10/library/concurrent.html
# download =  https://docs.python.org/3.10/library/concurrent.futures.html
# analyze_html= https://docs.python.org/3.10/library/concurrent.futures.html
# download =  https://docs.python.org/3.10/library/subprocess.html
# analyze_html= https://docs.python.org/3.10/library/subprocess.html
# download =  https://docs.python.org/3.10/library/sched.html
# analyze_html= https://docs.python.org/3.10/library/sched.html
# download =  https://docs.python.org/3.10/library/queue.html
# analyze_html= https://docs.python.org/3.10/library/queue.html
# download =  https://docs.python.org/3.10/library/contextvars.html
# analyze_html= https://docs.python.org/3.10/library/contextvars.html
# download =  https://docs.python.org/3.10/library/_thread.html
# analyze_html= https://docs.python.org/3.10/library/_thread.html
# download =  https://docs.python.org/3.10/library/ipc.html
# analyze_html= https://docs.python.org/3.10/library/ipc.html
# download =  https://docs.python.org/3.10/library/asyncio.html
# analyze_html= https://docs.python.org/3.10/library/asyncio.html
# download =  https://docs.python.org/3.10/library/asyncio-task.html
# analyze_html= https://docs.python.org/3.10/library/asyncio-task.html
# download =  https://docs.python.org/3.10/library/asyncio-stream.html
# analyze_html= https://docs.python.org/3.10/library/asyncio-stream.html
# download =  https://docs.python.org/3.10/library/asyncio-sync.html
# analyze_html= https://docs.python.org/3.10/library/asyncio-sync.html
# download =  https://docs.python.org/3.10/library/asyncio-subprocess.html
# analyze_html= https://docs.python.org/3.10/library/asyncio-subprocess.html
# download =  https://docs.python.org/3.10/library/asyncio-queue.html
# analyze_html= https://docs.python.org/3.10/library/asyncio-queue.html
# download =  https://docs.python.org/3.10/library/asyncio-exceptions.html
# analyze_html= https://docs.python.org/3.10/library/asyncio-exceptions.html
# download =  https://docs.python.org/3.10/library/asyncio-eventloop.html
# analyze_html= https://docs.python.org/3.10/library/asyncio-eventloop.html
# download =  https://docs.python.org/3.10/library/asyncio-future.html
# analyze_html= https://docs.python.org/3.10/library/asyncio-future.html
# download =  https://docs.python.org/3.10/library/asyncio-protocol.html
# analyze_html= https://docs.python.org/3.10/library/asyncio-protocol.html
# download =  https://docs.python.org/3.10/library/asyncio-policy.html
# analyze_html= https://docs.python.org/3.10/library/asyncio-policy.html
# download =  https://docs.python.org/3.10/library/asyncio-platforms.html
# analyze_html= https://docs.python.org/3.10/library/asyncio-platforms.html
# download =  https://docs.python.org/3.10/library/asyncio-api-index.html
# analyze_html= https://docs.python.org/3.10/library/asyncio-api-index.html
# download =  https://docs.python.org/3.10/library/asyncio-llapi-index.html
# analyze_html= https://docs.python.org/3.10/library/asyncio-llapi-index.html
# download =  https://docs.python.org/3.10/library/asyncio-dev.html
# analyze_html= https://docs.python.org/3.10/library/asyncio-dev.html
# download =  https://docs.python.org/3.10/library/socket.html
# analyze_html= https://docs.python.org/3.10/library/socket.html
# download =  https://docs.python.org/3.10/library/ssl.html
# analyze_html= https://docs.python.org/3.10/library/ssl.html
# download =  https://docs.python.org/3.10/library/select.html
# analyze_html= https://docs.python.org/3.10/library/select.html
# download =  https://docs.python.org/3.10/library/selectors.html
# analyze_html= https://docs.python.org/3.10/library/selectors.html
# download =  https://docs.python.org/3.10/library/signal.html
# analyze_html= https://docs.python.org/3.10/library/signal.html
# download =  https://docs.python.org/3.10/library/mmap.html
# analyze_html= https://docs.python.org/3.10/library/mmap.html
# download =  https://docs.python.org/3.10/library/netdata.html
# analyze_html= https://docs.python.org/3.10/library/netdata.html
# download =  https://docs.python.org/3.10/library/email.html
# analyze_html= https://docs.python.org/3.10/library/email.html
# download =  https://docs.python.org/3.10/library/email.message.html
# analyze_html= https://docs.python.org/3.10/library/email.message.html
# download =  https://docs.python.org/3.10/library/email.parser.html
# analyze_html= https://docs.python.org/3.10/library/email.parser.html
# download =  https://docs.python.org/3.10/library/email.generator.html
# analyze_html= https://docs.python.org/3.10/library/email.generator.html
# download =  https://docs.python.org/3.10/library/email.policy.html
# analyze_html= https://docs.python.org/3.10/library/email.policy.html
# download =  https://docs.python.org/3.10/library/email.errors.html
# analyze_html= https://docs.python.org/3.10/library/email.errors.html
# download =  https://docs.python.org/3.10/library/email.headerregistry.html
# analyze_html= https://docs.python.org/3.10/library/email.headerregistry.html
# download =  https://docs.python.org/3.10/library/email.contentmanager.html
# analyze_html= https://docs.python.org/3.10/library/email.contentmanager.html
# download =  https://docs.python.org/3.10/library/email.examples.html
# analyze_html= https://docs.python.org/3.10/library/email.examples.html
# download =  https://docs.python.org/3.10/library/email.compat32-message.html
# analyze_html= https://docs.python.org/3.10/library/email.compat32-message.html
# download =  https://docs.python.org/3.10/library/email.mime.html
# analyze_html= https://docs.python.org/3.10/library/email.mime.html
# download =  https://docs.python.org/3.10/library/email.header.html
# analyze_html= https://docs.python.org/3.10/library/email.header.html
# download =  https://docs.python.org/3.10/library/email.charset.html
# analyze_html= https://docs.python.org/3.10/library/email.charset.html
# download =  https://docs.python.org/3.10/library/email.encoders.html
# analyze_html= https://docs.python.org/3.10/library/email.encoders.html
# download =  https://docs.python.org/3.10/library/email.utils.html
# analyze_html= https://docs.python.org/3.10/library/email.utils.html
# download =  https://docs.python.org/3.10/library/email.iterators.html
# analyze_html= https://docs.python.org/3.10/library/email.iterators.html
# download =  https://docs.python.org/3.10/library/json.html
# analyze_html= https://docs.python.org/3.10/library/json.html
# download =  https://docs.python.org/3.10/library/mailcap.html
# analyze_html= https://docs.python.org/3.10/library/mailcap.html
# download =  https://docs.python.org/3.10/library/mailbox.html
# analyze_html= https://docs.python.org/3.10/library/mailbox.html
# download =  https://docs.python.org/3.10/library/mimetypes.html
# analyze_html= https://docs.python.org/3.10/library/mimetypes.html
# download =  https://docs.python.org/3.10/library/base64.html
# analyze_html= https://docs.python.org/3.10/library/base64.html
# download =  https://docs.python.org/3.10/library/binhex.html
# analyze_html= https://docs.python.org/3.10/library/binhex.html
# download =  https://docs.python.org/3.10/library/binascii.html
# analyze_html= https://docs.python.org/3.10/library/binascii.html
# download =  https://docs.python.org/3.10/library/quopri.html
# analyze_html= https://docs.python.org/3.10/library/quopri.html
# download =  https://docs.python.org/3.10/library/markup.html
# analyze_html= https://docs.python.org/3.10/library/markup.html
# download =  https://docs.python.org/3.10/library/html.html
# analyze_html= https://docs.python.org/3.10/library/html.html
# download =  https://docs.python.org/3.10/library/html.parser.html
# analyze_html= https://docs.python.org/3.10/library/html.parser.html
# download =  https://docs.python.org/3.10/library/html.entities.html
# analyze_html= https://docs.python.org/3.10/library/html.entities.html
# download =  https://docs.python.org/3.10/library/xml.html
# analyze_html= https://docs.python.org/3.10/library/xml.html
# download =  https://docs.python.org/3.10/library/xml.etree.elementtree.html
# analyze_html= https://docs.python.org/3.10/library/xml.etree.elementtree.html
# download =  https://docs.python.org/3.10/library/xml.dom.html
# analyze_html= https://docs.python.org/3.10/library/xml.dom.html
# download =  https://docs.python.org/3.10/library/xml.dom.minidom.html
# analyze_html= https://docs.python.org/3.10/library/xml.dom.minidom.html
# download =  https://docs.python.org/3.10/library/xml.dom.pulldom.html
# analyze_html= https://docs.python.org/3.10/library/xml.dom.pulldom.html
# download =  https://docs.python.org/3.10/library/xml.sax.html
# analyze_html= https://docs.python.org/3.10/library/xml.sax.html
# download =  https://docs.python.org/3.10/library/xml.sax.handler.html
# analyze_html= https://docs.python.org/3.10/library/xml.sax.handler.html
# download =  https://docs.python.org/3.10/library/xml.sax.utils.html
# analyze_html= https://docs.python.org/3.10/library/xml.sax.utils.html
# download =  https://docs.python.org/3.10/library/xml.sax.reader.html
# analyze_html= https://docs.python.org/3.10/library/xml.sax.reader.html
# download =  https://docs.python.org/3.10/library/pyexpat.html
# analyze_html= https://docs.python.org/3.10/library/pyexpat.html
# download =  https://docs.python.org/3.10/library/internet.html
# analyze_html= https://docs.python.org/3.10/library/internet.html
# download =  https://docs.python.org/3.10/library/webbrowser.html
# analyze_html= https://docs.python.org/3.10/library/webbrowser.html
# download =  https://docs.python.org/3.10/library/wsgiref.html
# analyze_html= https://docs.python.org/3.10/library/wsgiref.html
# download =  https://docs.python.org/3.10/library/urllib.html
# analyze_html= https://docs.python.org/3.10/library/urllib.html
# download =  https://docs.python.org/3.10/library/urllib.request.html
# analyze_html= https://docs.python.org/3.10/library/urllib.request.html
# download =  https://docs.python.org/3.10/library/urllib.parse.html
# analyze_html= https://docs.python.org/3.10/library/urllib.parse.html
# download =  https://docs.python.org/3.10/library/urllib.error.html
# analyze_html= https://docs.python.org/3.10/library/urllib.error.html
# download =  https://docs.python.org/3.10/library/urllib.robotparser.html
# analyze_html= https://docs.python.org/3.10/library/urllib.robotparser.html
# download =  https://docs.python.org/3.10/library/http.html
# analyze_html= https://docs.python.org/3.10/library/http.html
# download =  https://docs.python.org/3.10/library/http.client.html
# analyze_html= https://docs.python.org/3.10/library/http.client.html
# download =  https://docs.python.org/3.10/library/ftplib.html
# analyze_html= https://docs.python.org/3.10/library/ftplib.html
# download =  https://docs.python.org/3.10/library/poplib.html
# analyze_html= https://docs.python.org/3.10/library/poplib.html
# download =  https://docs.python.org/3.10/library/imaplib.html
# analyze_html= https://docs.python.org/3.10/library/imaplib.html
# download =  https://docs.python.org/3.10/library/smtplib.html
# analyze_html= https://docs.python.org/3.10/library/smtplib.html
# download =  https://docs.python.org/3.10/library/uuid.html
# analyze_html= https://docs.python.org/3.10/library/uuid.html
# download =  https://docs.python.org/3.10/library/socketserver.html
# analyze_html= https://docs.python.org/3.10/library/socketserver.html
# download =  https://docs.python.org/3.10/library/http.server.html
# analyze_html= https://docs.python.org/3.10/library/http.server.html
# download =  https://docs.python.org/3.10/library/http.cookies.html
# analyze_html= https://docs.python.org/3.10/library/http.cookies.html
# download =  https://docs.python.org/3.10/library/http.cookiejar.html
# analyze_html= https://docs.python.org/3.10/library/http.cookiejar.html
# download =  https://docs.python.org/3.10/library/xmlrpc.html
# analyze_html= https://docs.python.org/3.10/library/xmlrpc.html
# download =  https://docs.python.org/3.10/library/xmlrpc.client.html
# analyze_html= https://docs.python.org/3.10/library/xmlrpc.client.html
# download =  https://docs.python.org/3.10/library/xmlrpc.server.html
# analyze_html= https://docs.python.org/3.10/library/xmlrpc.server.html
# download =  https://docs.python.org/3.10/library/ipaddress.html
# analyze_html= https://docs.python.org/3.10/library/ipaddress.html
# download =  https://docs.python.org/3.10/library/mm.html
# analyze_html= https://docs.python.org/3.10/library/mm.html
# download =  https://docs.python.org/3.10/library/wave.html
# analyze_html= https://docs.python.org/3.10/library/wave.html
# download =  https://docs.python.org/3.10/library/colorsys.html
# analyze_html= https://docs.python.org/3.10/library/colorsys.html
# download =  https://docs.python.org/3.10/library/i18n.html
# analyze_html= https://docs.python.org/3.10/library/i18n.html
# download =  https://docs.python.org/3.10/library/gettext.html
# analyze_html= https://docs.python.org/3.10/library/gettext.html
# download =  https://docs.python.org/3.10/library/locale.html
# analyze_html= https://docs.python.org/3.10/library/locale.html
# download =  https://docs.python.org/3.10/library/frameworks.html
# analyze_html= https://docs.python.org/3.10/library/frameworks.html
# download =  https://docs.python.org/3.10/library/turtle.html
# analyze_html= https://docs.python.org/3.10/library/turtle.html
# download =  https://docs.python.org/3.10/library/cmd.html
# analyze_html= https://docs.python.org/3.10/library/cmd.html
# download =  https://docs.python.org/3.10/library/shlex.html
# analyze_html= https://docs.python.org/3.10/library/shlex.html
# download =  https://docs.python.org/3.10/library/tk.html
# analyze_html= https://docs.python.org/3.10/library/tk.html
# download =  https://docs.python.org/3.10/library/tkinter.html
# analyze_html= https://docs.python.org/3.10/library/tkinter.html
# download =  https://docs.python.org/3.10/library/tkinter.colorchooser.html
# analyze_html= https://docs.python.org/3.10/library/tkinter.colorchooser.html
# download =  https://docs.python.org/3.10/library/tkinter.font.html
# analyze_html= https://docs.python.org/3.10/library/tkinter.font.html
# download =  https://docs.python.org/3.10/library/dialog.html
# analyze_html= https://docs.python.org/3.10/library/dialog.html
# download =  https://docs.python.org/3.10/library/tkinter.messagebox.html
# analyze_html= https://docs.python.org/3.10/library/tkinter.messagebox.html
# download =  https://docs.python.org/3.10/library/tkinter.scrolledtext.html
# analyze_html= https://docs.python.org/3.10/library/tkinter.scrolledtext.html
# download =  https://docs.python.org/3.10/library/tkinter.dnd.html
# analyze_html= https://docs.python.org/3.10/library/tkinter.dnd.html
# download =  https://docs.python.org/3.10/library/tkinter.ttk.html
# analyze_html= https://docs.python.org/3.10/library/tkinter.ttk.html
# download =  https://docs.python.org/3.10/library/tkinter.tix.html
# analyze_html= https://docs.python.org/3.10/library/tkinter.tix.html
# download =  https://docs.python.org/3.10/library/idle.html
# analyze_html= https://docs.python.org/3.10/library/idle.html
# download =  https://docs.python.org/3.10/library/development.html
# analyze_html= https://docs.python.org/3.10/library/development.html
# download =  https://docs.python.org/3.10/library/typing.html
# analyze_html= https://docs.python.org/3.10/library/typing.html
# download =  https://docs.python.org/3.10/library/pydoc.html
# analyze_html= https://docs.python.org/3.10/library/pydoc.html
# download =  https://docs.python.org/3.10/library/devmode.html
# analyze_html= https://docs.python.org/3.10/library/devmode.html
# download =  https://docs.python.org/3.10/library/doctest.html
# analyze_html= https://docs.python.org/3.10/library/doctest.html
# download =  https://docs.python.org/3.10/library/unittest.html
# analyze_html= https://docs.python.org/3.10/library/unittest.html
# download =  https://docs.python.org/3.10/library/unittest.mock.html
# analyze_html= https://docs.python.org/3.10/library/unittest.mock.html
# download =  https://docs.python.org/3.10/library/unittest.mock-examples.html
# analyze_html= https://docs.python.org/3.10/library/unittest.mock-examples.html
# download =  https://docs.python.org/3.10/library/2to3.html
# analyze_html= https://docs.python.org/3.10/library/2to3.html
# download =  https://docs.python.org/3.10/library/test.html
# analyze_html= https://docs.python.org/3.10/library/test.html
# download =  https://docs.python.org/3.10/library/debug.html
# analyze_html= https://docs.python.org/3.10/library/debug.html
# download =  https://docs.python.org/3.10/library/audit_events.html
# analyze_html= https://docs.python.org/3.10/library/audit_events.html
# download =  https://docs.python.org/3.10/library/bdb.html
# analyze_html= https://docs.python.org/3.10/library/bdb.html
# download =  https://docs.python.org/3.10/library/faulthandler.html
# analyze_html= https://docs.python.org/3.10/library/faulthandler.html
# download =  https://docs.python.org/3.10/library/pdb.html
# analyze_html= https://docs.python.org/3.10/library/pdb.html
# download =  https://docs.python.org/3.10/library/profile.html
# analyze_html= https://docs.python.org/3.10/library/profile.html
# download =  https://docs.python.org/3.10/library/timeit.html
# analyze_html= https://docs.python.org/3.10/library/timeit.html
# download =  https://docs.python.org/3.10/library/trace.html
# analyze_html= https://docs.python.org/3.10/library/trace.html
# download =  https://docs.python.org/3.10/library/tracemalloc.html
# analyze_html= https://docs.python.org/3.10/library/tracemalloc.html
# download =  https://docs.python.org/3.10/library/distribution.html
# analyze_html= https://docs.python.org/3.10/library/distribution.html
# download =  https://docs.python.org/3.10/library/distutils.html
# analyze_html= https://docs.python.org/3.10/library/distutils.html
# download =  https://docs.python.org/3.10/library/ensurepip.html
# analyze_html= https://docs.python.org/3.10/library/ensurepip.html
# download =  https://docs.python.org/3.10/library/venv.html
# analyze_html= https://docs.python.org/3.10/library/venv.html
# download =  https://docs.python.org/3.10/library/zipapp.html
# analyze_html= https://docs.python.org/3.10/library/zipapp.html
# download =  https://docs.python.org/3.10/library/python.html
# analyze_html= https://docs.python.org/3.10/library/python.html
# download =  https://docs.python.org/3.10/library/sys.html
# analyze_html= https://docs.python.org/3.10/library/sys.html
# download =  https://docs.python.org/3.10/library/sysconfig.html
# analyze_html= https://docs.python.org/3.10/library/sysconfig.html
# download =  https://docs.python.org/3.10/library/builtins.html
# analyze_html= https://docs.python.org/3.10/library/builtins.html
# download =  https://docs.python.org/3.10/library/__main__.html
# analyze_html= https://docs.python.org/3.10/library/__main__.html
# download =  https://docs.python.org/3.10/library/warnings.html
# analyze_html= https://docs.python.org/3.10/library/warnings.html
# download =  https://docs.python.org/3.10/library/dataclasses.html
# analyze_html= https://docs.python.org/3.10/library/dataclasses.html
# download =  https://docs.python.org/3.10/library/contextlib.html
# analyze_html= https://docs.python.org/3.10/library/contextlib.html
# download =  https://docs.python.org/3.10/library/abc.html
# analyze_html= https://docs.python.org/3.10/library/abc.html
# download =  https://docs.python.org/3.10/library/atexit.html
# analyze_html= https://docs.python.org/3.10/library/atexit.html
# download =  https://docs.python.org/3.10/library/traceback.html
# analyze_html= https://docs.python.org/3.10/library/traceback.html
# download =  https://docs.python.org/3.10/library/__future__.html
# analyze_html= https://docs.python.org/3.10/library/__future__.html
# download =  https://docs.python.org/3.10/library/gc.html
# analyze_html= https://docs.python.org/3.10/library/gc.html
# download =  https://docs.python.org/3.10/library/inspect.html
# analyze_html= https://docs.python.org/3.10/library/inspect.html
# download =  https://docs.python.org/3.10/library/site.html
# analyze_html= https://docs.python.org/3.10/library/site.html
# download =  https://docs.python.org/3.10/library/custominterp.html
# analyze_html= https://docs.python.org/3.10/library/custominterp.html
# download =  https://docs.python.org/3.10/library/code.html
# analyze_html= https://docs.python.org/3.10/library/code.html
# download =  https://docs.python.org/3.10/library/codeop.html
# analyze_html= https://docs.python.org/3.10/library/codeop.html
# download =  https://docs.python.org/3.10/library/modules.html
# analyze_html= https://docs.python.org/3.10/library/modules.html
# download =  https://docs.python.org/3.10/library/zipimport.html
# analyze_html= https://docs.python.org/3.10/library/zipimport.html
# download =  https://docs.python.org/3.10/library/pkgutil.html
# analyze_html= https://docs.python.org/3.10/library/pkgutil.html
# download =  https://docs.python.org/3.10/library/modulefinder.html
# analyze_html= https://docs.python.org/3.10/library/modulefinder.html
# download =  https://docs.python.org/3.10/library/runpy.html
# analyze_html= https://docs.python.org/3.10/library/runpy.html
# download =  https://docs.python.org/3.10/library/importlib.html
# analyze_html= https://docs.python.org/3.10/library/importlib.html
# download =  https://docs.python.org/3.10/library/importlib.metadata.html
# analyze_html= https://docs.python.org/3.10/library/importlib.metadata.html
# download =  https://docs.python.org/3.10/library/language.html
# analyze_html= https://docs.python.org/3.10/library/language.html
# download =  https://docs.python.org/3.10/library/ast.html
# analyze_html= https://docs.python.org/3.10/library/ast.html
# download =  https://docs.python.org/3.10/library/symtable.html
# analyze_html= https://docs.python.org/3.10/library/symtable.html
# download =  https://docs.python.org/3.10/library/token.html
# analyze_html= https://docs.python.org/3.10/library/token.html
# download =  https://docs.python.org/3.10/library/keyword.html
# analyze_html= https://docs.python.org/3.10/library/keyword.html
# download =  https://docs.python.org/3.10/library/tokenize.html
# analyze_html= https://docs.python.org/3.10/library/tokenize.html
# download =  https://docs.python.org/3.10/library/tabnanny.html
# analyze_html= https://docs.python.org/3.10/library/tabnanny.html
# download =  https://docs.python.org/3.10/library/pyclbr.html
# analyze_html= https://docs.python.org/3.10/library/pyclbr.html
# download =  https://docs.python.org/3.10/library/py_compile.html
# analyze_html= https://docs.python.org/3.10/library/py_compile.html
# download =  https://docs.python.org/3.10/library/compileall.html
# analyze_html= https://docs.python.org/3.10/library/compileall.html
# download =  https://docs.python.org/3.10/library/dis.html
# analyze_html= https://docs.python.org/3.10/library/dis.html
# download =  https://docs.python.org/3.10/library/pickletools.html
# analyze_html= https://docs.python.org/3.10/library/pickletools.html
# download =  https://docs.python.org/3.10/library/windows.html
# analyze_html= https://docs.python.org/3.10/library/windows.html
# download =  https://docs.python.org/3.10/library/msvcrt.html
# analyze_html= https://docs.python.org/3.10/library/msvcrt.html
# download =  https://docs.python.org/3.10/library/winreg.html
# analyze_html= https://docs.python.org/3.10/library/winreg.html
# download =  https://docs.python.org/3.10/library/winsound.html
# analyze_html= https://docs.python.org/3.10/library/winsound.html
# download =  https://docs.python.org/3.10/library/unix.html
# analyze_html= https://docs.python.org/3.10/library/unix.html
# download =  https://docs.python.org/3.10/library/posix.html
# analyze_html= https://docs.python.org/3.10/library/posix.html
# download =  https://docs.python.org/3.10/library/pwd.html
# analyze_html= https://docs.python.org/3.10/library/pwd.html
# download =  https://docs.python.org/3.10/library/grp.html
# analyze_html= https://docs.python.org/3.10/library/grp.html
# download =  https://docs.python.org/3.10/library/termios.html
# analyze_html= https://docs.python.org/3.10/library/termios.html
# download =  https://docs.python.org/3.10/library/tty.html
# analyze_html= https://docs.python.org/3.10/library/tty.html
# download =  https://docs.python.org/3.10/library/pty.html
# analyze_html= https://docs.python.org/3.10/library/pty.html
# download =  https://docs.python.org/3.10/library/fcntl.html
# analyze_html= https://docs.python.org/3.10/library/fcntl.html
# download =  https://docs.python.org/3.10/library/resource.html
# analyze_html= https://docs.python.org/3.10/library/resource.html
# download =  https://docs.python.org/3.10/library/syslog.html
# analyze_html= https://docs.python.org/3.10/library/syslog.html
# download =  https://docs.python.org/3.10/library/superseded.html
# analyze_html= https://docs.python.org/3.10/library/superseded.html
# download =  https://docs.python.org/3.10/library/aifc.html
# analyze_html= https://docs.python.org/3.10/library/aifc.html
# download =  https://docs.python.org/3.10/library/asynchat.html
# analyze_html= https://docs.python.org/3.10/library/asynchat.html
# download =  https://docs.python.org/3.10/library/asyncore.html
# analyze_html= https://docs.python.org/3.10/library/asyncore.html
# download =  https://docs.python.org/3.10/library/audioop.html
# analyze_html= https://docs.python.org/3.10/library/audioop.html
# download =  https://docs.python.org/3.10/library/cgi.html
# analyze_html= https://docs.python.org/3.10/library/cgi.html
# download =  https://docs.python.org/3.10/library/cgitb.html
# analyze_html= https://docs.python.org/3.10/library/cgitb.html
# download =  https://docs.python.org/3.10/library/chunk.html
# analyze_html= https://docs.python.org/3.10/library/chunk.html
# download =  https://docs.python.org/3.10/library/crypt.html
# analyze_html= https://docs.python.org/3.10/library/crypt.html
# download =  https://docs.python.org/3.10/library/imghdr.html
# analyze_html= https://docs.python.org/3.10/library/imghdr.html
# download =  https://docs.python.org/3.10/library/imp.html
# analyze_html= https://docs.python.org/3.10/library/imp.html
# download =  https://docs.python.org/3.10/library/msilib.html
# analyze_html= https://docs.python.org/3.10/library/msilib.html
# download =  https://docs.python.org/3.10/library/nntplib.html
# analyze_html= https://docs.python.org/3.10/library/nntplib.html
# download =  https://docs.python.org/3.10/library/nis.html
# analyze_html= https://docs.python.org/3.10/library/nis.html
# download =  https://docs.python.org/3.10/library/optparse.html
# analyze_html= https://docs.python.org/3.10/library/optparse.html
# download =  https://docs.python.org/3.10/library/ossaudiodev.html
# analyze_html= https://docs.python.org/3.10/library/ossaudiodev.html
# download =  https://docs.python.org/3.10/library/pipes.html
# analyze_html= https://docs.python.org/3.10/library/pipes.html
# download =  https://docs.python.org/3.10/library/smtpd.html
# analyze_html= https://docs.python.org/3.10/library/smtpd.html
# download =  https://docs.python.org/3.10/library/sndhdr.html
# analyze_html= https://docs.python.org/3.10/library/sndhdr.html
# download =  https://docs.python.org/3.10/library/spwd.html
# analyze_html= https://docs.python.org/3.10/library/spwd.html
# download =  https://docs.python.org/3.10/library/sunau.html
# analyze_html= https://docs.python.org/3.10/library/sunau.html
# download =  https://docs.python.org/3.10/library/telnetlib.html
# analyze_html= https://docs.python.org/3.10/library/telnetlib.html
# download =  https://docs.python.org/3.10/library/uu.html
# analyze_html= https://docs.python.org/3.10/library/uu.html
# download =  https://docs.python.org/3.10/library/xdrlib.html
# analyze_html= https://docs.python.org/3.10/library/xdrlib.html
# download =  https://docs.python.org/3.10/library/security_warnings.html
# analyze_html= https://docs.python.org/3.10/library/security_warnings.html

# %%
url = "http://example.com/html/a.html"
t = urlparse(url)
t.netloc        # example.com
t.path          # /html/a.html
# Out:
# '/html/a.html'

# %%
import http.server

http.server --directoy ./docs.python.org/3.10
# Out:
#   Input In [159]
#     http.server --directoy ./docs.python.org/3.10
#                             ^
# SyntaxError: invalid syntax

# %%
### requests 패키지를 이용한 접근...

# %%
### 파이썬으로 로그인하기
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# 아이디와 비밀번호 지정
USER = "dongsun0713"
PASS = "ehdtjs5001!"

## 세션 시작
session = requests.session()
## 로그인하기
login_info ={
    "m_id" : USER,
    "m_pw" : PASS
}

url_login = "https://www.hanbit.co.kr/member/login.html"
res = session.post(url_login, data=login_info)
res.raise_for_status()  # 오류가 발생하면 에외를 발생

# 마이페이지에 접근
url_mypage = "https://www.hanbit.co.kr/myhanbit/myhanbit.html"
res = session.get(url_mypage)
res.raise_for_status()

soup = BeautifulSoup(res.txt, "html.parser")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\PythonProject\Day20220506\Day20220506.ipynb Cell 9' in <cell line: 27>()
#      <a href='vscode-notebook-cell:/c%3A/PythonProject/Day20220506/Day20220506.ipynb#ch0000008?line=23'>24</a> res = session.get(url_mypage)
#      <a href='vscode-notebook-cell:/c%3A/PythonProject/Day20220506/Day20220506.ipynb#ch0000008?line=24'>25</a> res.raise_for_status()
# ---> <a href='vscode-notebook-cell:/c%3A/PythonProject/Day20220506/Day20220506.ipynb#ch0000008?line=26'>27</a> soup = BeautifulSoup(res.txt, "html.parser")
#
# AttributeError: 'Response' object has no attribute 'txt'

# %%
## reqeusts 모듈의 메서드

# get 요청
r = requests.get("http://www.naver.com")

# post 요청
formdata = {"key1":"value1", "key2":"value2"}
r = requests.post("http://example.com",data=formdata)

# %%
r = requests.put("http://httpbin.org/put")          ## 데이터를 업로드할때 put을 사용한다.(http메서드)
r = requests.delete("http://httpbin.org/delete")    ## 데이터 삭제
r = requests.head("http://www.google.com")         ## 데이터를 제외한 서버로부터 받은 헤더 정보만 받음
print(requests.get("https://www.google.com").content)

# %%
from http.server import HTTPServer, SimpleHTTPRequestHandler

server = HTTPServer((('0.0.0.0',8100)), SimpleHTTPRequestHandler)
server.serve_forever()

# %%
from selenium import webdriver
USER = "dongsun0713"
PASS = "ehdtjs5001!"

path = "C:\\webdriver\\chromedriver"
driver = webdriver.Chrome(path)

# 한빛 로그인페이지 
url_login = "https://www.hanbit.co.kr/member/login.html"
driver.get(url_login)

## 로그인 박스에 ID와 비밀번호 입력하기
id = driver.find_element_by_id("m_id")
id.clear()
id.send_keys(USER)
passwd = driver.find_element_by_id("m_passwd")
passwd.clear()
passwd.send_keys(PASS)

# 로그인 버튼 클릭
driver.find_element_by_class_name("btn_login").click()

# 마이페이지로 이동
driver.find_element_by_class_name("myhanbit").click()

# 가지고있는 마일리지
mileage = driver.find_element_by_css_selector(".mileage_section1 span")
print(f"한빛 마일리지 : {mileage.text}점")

# 한빛이코인 출력
coin = driver.find_element_by_css_selector(".mileage_section2 span")
print(f"한빛 이코인 : {coin.text}원")

# %%
from selenium import webdriver
from random import randint
import os.path, time, re


USER = "yw028594"
PASS = ["spdla13258791!"]

path = "C:\\webdriver\\chromedriver"
driver = webdriver.Chrome(path)

url_login = "https://www.naver.com/"
driver.get(url_login)

driver.find_element_by_class_name("link_login").click()

id = driver.find_element_by_id("id")
id.clear()
id.send_keys(USER)

passwd = driver.find_element_by_id("pw")
passwd.clear()
passwd.send_keys(PASS)

# 로그인 버튼 클릭
driver.find_element_by_class_name("btn_login").click()

driver.find_element_by_id("new.dontsave").click()

driver.get("http://order.pay.naver.com/home")

mileage = driver.find_element_by_class_name("link strong")

print(f"마일리지 : {mileage.text}원")
# Out:
# C:\Users\a0104\AppData\Local\Temp\ipykernel_33016\1746108006.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# C:\Users\a0104\AppData\Local\Temp\ipykernel_33016\1746108006.py:15: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   driver.find_element_by_class_name("link_login").click()
# C:\Users\a0104\AppData\Local\Temp\ipykernel_33016\1746108006.py:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   id = driver.find_element_by_id("id")
# C:\Users\a0104\AppData\Local\Temp\ipykernel_33016\1746108006.py:21: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   passwd = driver.find_element_by_id("pw")
# C:\Users\a0104\AppData\Local\Temp\ipykernel_33016\1746108006.py:27: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   driver.find_element_by_class_name("btn_login").click()
# C:\Users\a0104\AppData\Local\Temp\ipykernel_33016\1746108006.py:29: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id("new.dontsave").click()
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# c:\PythonProject\Day20220506\Day20220506.ipynb Cell 14' in <cell line: 29>()
#      <a href='vscode-notebook-cell:/c%3A/PythonProject/Day20220506/Day20220506.ipynb#ch0000013?line=25'>26</a> # 로그인 버튼 클릭
#      <a href='vscode-notebook-cell:/c%3A/PythonProject/Day20220506/Day20220506.ipynb#ch0000013?line=26'>27</a> driver.find_element_by_class_name("btn_login").click()
# ---> <a href='vscode-notebook-cell:/c%3A/PythonProject/Day20220506/Day20220506.ipynb#ch0000013?line=28'>29</a> driver.find_element_by_id("new.dontsave").click()
#      <a href='vscode-notebook-cell:/c%3A/PythonProject/Day20220506/Day20220506.ipynb#ch0000013?line=30'>31</a> driver.get("http://order.pay.naver.com/home")
#      <a href='vscode-notebook-cell:/c%3A/PythonProject/Day20220506/Day20220506.ipynb#ch0000013?line=32'>33</a> mileage = driver.find_element_by_class_name("link strong")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\selenium\webdriver\remote\webdriver.py:473, in WebDriver.find_element_by_id(self, id_)
#     <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=451'>452</a> """Finds an element by id.
#     <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=452'>453</a>
#     <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=453'>454</a> :Args:
#    (...)
#     <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=465'>466</a>         element = driver.find_element_by_id('foo')
#     <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=466'>467</a> """
#     <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=467'>468</a> warnings.warn(
#     <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=468'>469</a>     "find_element_by_* commands are deprecated. Please use find_element() instead",
#     <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=469'>470</a>     DeprecationWarning,
#     <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=470'>471</a>     stacklevel=2,
#     <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=471'>472</a> )
# --> <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=472'>473</a> return self.find_element(by=By.ID, value=id_)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\selenium\webdriver\remote\webdriver.py:1248, in WebDriver.find_element(self, by, value)
#    <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=1244'>1245</a>     by = By.CSS_SELECTOR
#    <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=1245'>1246</a>     value = '[name="%s"]' % value
# -> <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=1247'>1248</a> return self.execute(Command.FIND_ELEMENT, {
#    <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=1248'>1249</a>     'using': by,
#    <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=1249'>1250</a>     'value': value})['value']
#
# File ~\AppData\Roaming\Python\Python310\site-packages\selenium\webdriver\remote\webdriver.py:425, in WebDriver.execute(self, driver_command, params)
#     <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=422'>423</a> response = self.command_executor.execute(driver_command, params)
#     <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=423'>424</a> if response:
# --> <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=424'>425</a>     self.error_handler.check_response(response)
#     <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=425'>426</a>     response['value'] = self._unwrap_value(
#     <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=426'>427</a>         response.get('value', None))
#     <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/webdriver.py?line=427'>428</a>     return response
#
# File ~\AppData\Roaming\Python\Python310\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/errorhandler.py?line=244'>245</a>         alert_text = value['alert'].get('text')
#     <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/errorhandler.py?line=245'>246</a>     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> <a href='file:///c%3A/Users/a0104/AppData/Roaming/Python/Python310/site-packages/selenium/webdriver/remote/errorhandler.py?line=246'>247</a> raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="new.dontsave"]"}
#   (Session info: chrome=101.0.4951.54)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x0087B8F3+2406643]
# 	Ordinal0 [0x0080AF31+1945393]
# 	Ordinal0 [0x006FC748+837448]
# 	Ordinal0 [0x007292E0+1020640]
# 	Ordinal0 [0x0072957B+1021307]
# 	Ordinal0 [0x00756372+1205106]
# 	Ordinal0 [0x007442C4+1131204]
# 	Ordinal0 [0x00754682+1197698]
# 	Ordinal0 [0x00744096+1130646]
# 	Ordinal0 [0x0071E636+976438]
# 	Ordinal0 [0x0071F546+980294]
# 	GetHandleVerifier [0x00AE9612+2498066]
# 	GetHandleVerifier [0x00ADC920+2445600]
# 	GetHandleVerifier [0x00914F2A+579370]
# 	GetHandleVerifier [0x00913D36+574774]
# 	Ordinal0 [0x00811C0B+1973259]
# 	Ordinal0 [0x00816688+1992328]
# 	Ordinal0 [0x00816775+1992565]
# 	Ordinal0 [0x0081F8D1+2029777]
# 	BaseThreadInitThunk [0x7710FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x776C7A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x776C7A4E+238]

# %%
# Out:
# s
# p
# d
# l
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\PythonProject\Day20220506\Day20220506.ipynb Cell 15' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/PythonProject/Day20220506/Day20220506.ipynb#ch0000014?line=1'>2</a> for i in PASS:
#       <a href='vscode-notebook-cell:/c%3A/PythonProject/Day20220506/Day20220506.ipynb#ch0000014?line=2'>3</a>     print(i)
# ----> <a href='vscode-notebook-cell:/c%3A/PythonProject/Day20220506/Day20220506.ipynb#ch0000014?line=3'>4</a>     time.sleep(3)
#
# KeyboardInterrupt:
